# %%
#GCD
# num1=int(input('Enter first number'))
# num2= int(input('Enter second number'))
# smallest=0
# if num1>num2:
#    smallest=num1
# else:
#      smallest=num2
# for i in range(1,smallest):
#     if num1 % i==0 & num2 % i==0 :
#       print('the greatest common divisor of ',num1 ,' and ',num2 ,' is ',i)



# #PRIME NUMBERS
# def isPrime(num):
#     for ( i in range(2,num)):
#         if num %i ==0:
#             print(i)

# for j in range(1,10000):
#     isPrime(j)


    
# def hyponuse( base , height):
#     return(base*2+height**2)

# base,height=input('Enter Base').split()
# base,height=float(base),float(height)
# print('Hypotenuse',hyponuse(base,height))
    
    
    #TASK 2
    
    #Distance
# def distance(x1,y1,x2,y2):
#     x3=x1-x2
#     y3=y1-y2
#     return x3,y3
    
        
# x1,y1=input('Enter the first point :').split()
# x1,y1=float(x1),float(y1)
# x2,y2=input('Enter the first point :').split()
# x2,y2=float(x2),float(y2)
# print('Distance between ( ',x1,y1,') and (',x2,y2,') is' ,distance(x1,y1,x2,y2))


#TASK 3
# def reverse(num):
#     return num [::-1]


# num=input('Enter Number between 1 and 9999')
# print('The number with its digits reversed is ',reverse(num))


# #TASK 4
# def isPrime(num):
#     for i in range(2, num):
#         if (num % i) == 0:
#             return False
#     return True
   
# num=int(input('Enter number'))
# if isPrime(num):
#     print(num,'is prime')
# else:
#       print(num,'is not prime')



#TASK 5
# def qualityPoints(num):
#     if num>=90 and num<=100:
#         return 4
#     elif num>=80 and num<90:
#         return 3
#     elif num >=70 and num<80:
#         return 2
#     elif num>=60 and num <70:
#         return 1
#     else:
#         return 0
    
# num=int(input('Enter the student\'s average'))
# print(num ,'on a 4 point scale is ',qualityPoints(num))
      
      
      #TASK 6
# def is_bouncy(num):
#           larger=False
#           smaller=False
#           str_list= str(num)
#           for i in range(1,len(str_list)):
#               if str_list[i]>str_list[i-1]:
#                   larger=True
#               if str_list[i]<str_list[i-1]:
#                    smaller=True
#               if larger==True and smaller==True:
#                   return True
#           return False          
      
      
# for j in range(1000,10000):
#     if is_bouncy(j):
#         print(j ,' ')
  
  
  #Task 8
# def fact(n):
#       product=1
#       for k in range(1,n+1):
#            product*=k
#       return product
    
# def binom(n,k):
      
#       n_fact= fact(n) #n!
#       k_fact=fact(k)#K!
#       result=(n_fact)/k_fact*(n_fact - k_fact)  #n! / k! * n-k!
#       return result
      
      
    #TASK 9
